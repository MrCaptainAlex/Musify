# %%
#Import Library
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import Data
# ts = pd.read_csv('/home/ale/IdeaProjects/Musify/TimeSeries/catalog_metrics.csv', header=0, parse_dates=[0],dayfirst=True,index_col=0)

# ts = pd.read_csv('catalog_metrics.csv', header=0, parse_dates=[0],dayfirst=True,index_col=0)
ts = pd.read_csv('user_metrics.csv', header=0, parse_dates=[0],dayfirst=True,index_col=0, usecols=[0,1])
ts
# Out:
#                                      value
# timestamp
# 2022-03-29 09:13:41.040999936+00:00      0
# 2022-03-29 09:13:46.038000128+00:00      0
# 2022-03-29 09:13:51.036999936+00:00      0
# 2022-03-29 09:13:56.036999936+00:00      0
# 2022-03-29 09:14:01.038000128+00:00      0
# ...                                    ...
# 2022-03-29 09:45:51.042000128+00:00    343
# 2022-03-29 09:45:56.039000064+00:00    344
# 2022-03-29 09:46:01.038000128+00:00    345
# 2022-03-29 09:46:06.036999936+00:00    346
# 2022-03-29 09:46:11.038000128+00:00    346
#
# [391 rows x 1 columns]

# %%
# resample data
tsr = ts.resample(rule='0.083T').mean()
tsr
# Out:
#                                   value
# timestamp
# 2022-03-29 09:13:36.600000+00:00    0.0
# 2022-03-29 09:13:41.580000+00:00    0.0
# 2022-03-29 09:13:46.560000+00:00    0.0
# 2022-03-29 09:13:51.540000+00:00    0.0
# 2022-03-29 09:13:56.520000+00:00    0.0
# ...                                 ...
# 2022-03-29 09:45:48.840000+00:00  343.0
# 2022-03-29 09:45:53.820000+00:00  344.0
# 2022-03-29 09:45:58.800000+00:00  345.0
# 2022-03-29 09:46:03.780000+00:00  346.0
# 2022-03-29 09:46:08.760000+00:00  346.0
#
# [393 rows x 1 columns]

# %%
#Highlight seasonability, reside, trend
from statsmodels.tsa.seasonal import seasonal_decompose
decomposedTs = seasonal_decompose(ts,model="add", period=15)
decomposedTs.plot()

# %%
#Split data  training e data test
train_data= tsr.iloc[:310]
test_data=tsr.iloc[310:]
#train_data
train_data.info()
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 310 entries, 2022-03-29 09:13:36.600000+00:00 to 2022-03-29 09:39:15.420000+00:00
# Freq: 4980L
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   value   308 non-null    float64
# dtypes: float64(1)
# memory usage: 4.8 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 83 entries, 2022-03-29 09:39:20.400000+00:00 to 2022-03-29 09:46:08.760000+00:00
# Freq: 4980L
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   value   83 non-null     float64
# dtypes: float64(1)
# memory usage: 1.3 KB

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
tsmodel = ExponentialSmoothing(train_data, trend="add",seasonal=None,seasonal_periods=1).fit()
prediction = tsmodel.forecast(100)
prediction
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/holtwinters/model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# 2022-03-29 09:39:20.400000+00:00   NaN
# 2022-03-29 09:39:25.380000+00:00   NaN
# 2022-03-29 09:39:30.360000+00:00   NaN
# 2022-03-29 09:39:35.340000+00:00   NaN
# 2022-03-29 09:39:40.320000+00:00   NaN
#                                     ..
# 2022-03-29 09:47:13.500000+00:00   NaN
# 2022-03-29 09:47:18.480000+00:00   NaN
# 2022-03-29 09:47:23.460000+00:00   NaN
# 2022-03-29 09:47:28.440000+00:00   NaN
# 2022-03-29 09:47:33.420000+00:00   NaN
# Freq: 4980L, Length: 100, dtype: float64

# %%
plt.figure(figsize=(24,10))

plt.ylabel('Values', fontsize=14)
plt.xlabel('Time', fontsize=14)
plt.title('Valori over time', fontsize=16)

plt.plot(test_data,"-",label='real')
plt.plot(prediction,"-",label = 'pred')
plt.legend(title='Series')
